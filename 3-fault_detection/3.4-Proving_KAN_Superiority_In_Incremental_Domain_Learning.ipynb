# %%
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
from src import *

plt.rcParams.update({'font.size': 18})

# %%
df_np_gt_ng_x, df_np_gt_ng_y = read_dataset(stage='classification')
df_np_lt_ng_x, df_np_lt_ng_y = read_dataset(stage='classification', discarded=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 df_np_gt_ng_x, df_np_gt_ng_y = read_dataset(stage='classification')
# ----> 2 df_np_lt_ng_x, df_np_lt_ng_y = read_dataset(stage='classification', discarded=True)
#
# File ~\Desktop\Ide Projects\PycharmProjects\PHM North America 2024 Challenge\src\dataset.py:63, in read_dataset(stage, normalization, dataset, merge, discarded, use_cache)
#      60         df_y['trq_target'] = df_x['trq_measured'] / (df_y['trq_margin'] / 100 + 1)
#      62 if stage == 'classification':
# ---> 63     df_x['trq_margin'] = __load_df(
#      64         f'../2-torque_target_probabilistic_regression/predictions{__dataset_suffix[dataset]}{__discarded_suffix[discarded]}.csv',
#      65         use_cache=use_cache)['trq_margin']
#      67 if normalization == 'normalize':
# ...

# %%
pyKAN: PHMNetwork = PyKAN([[len(df_np_gt_ng_x.columns), 0], [1, 0], [1, 0]], 'classification', grid_size=5, device='cpu')

# %%
pyKAN.load('fault_detection')
_, _, testset, _ = split_dataset(df_x, df_y['faulty'], train_ratio=0.01, standardize_y=False, max=1, seed=1)
pyKAN.test(testset)

# %%
# 3m
pyKAN.multi_train(df_x, df_y['faulty'], epochs=15, lr=0.05, train_ratio=0.90, prefix='IDL_1', times=1, batch_size=2048)

# %%
pyKAN.save('IDL_1')

# %%
# 1s
pyKAN.plot(scale=1.25, in_vars=list(map(to_latex, df_x.columns)))
